# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error
from math import sqrt
import os
import shutil
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
file_path = 'Country.xlsx'
data = pd.read_excel(file_path, sheet_name='Sheet4')
finaldata = data['Country'].tolist()
data
# Out:
#             Country
# 0       Afghanistan
# 1           Albania
# 2           Algeria
# 3    American Samoa
# 4           Andorra
# ..              ...
# 219       West Bank
# 220  Western Sahara
# 221           Yemen
# 222          Zambia
# 223        Zimbabwe
#
# [224 rows x 1 columns]

# %%
def list_files(directory):
    file_list = []
    files_l = []
    for root, directories, files in os.walk(directory):
        for filename in files:
            files_l.append(filename)
            file_list.append(os.path.join(root, filename))
    return files_l

folder_path = "Final_data"
files = list_files(folder_path)
files = [item for item in files if item != ".DS_Store"]
files2 = [file_name.replace('.csv', '') for file_name in files]


print(len(files2))
files2 = sorted(files2)
for file in files2:
    print(file)
# Out:
# 224
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Anguilla
# Antigua & Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia & Herzegovina
# Botswana
# Brazil
# British Virgin Islands
# Brunei
# Bulgaria
# Burkina Faso
# Burma
# Burundi
# Cambodia
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Rep.
# Chad
# Chile
# China
# Columbia
# Comoros
# Cook Islands
# Costa Rica
# Cote d_Ivoire
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Democratic Republic of the Congo
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# East Timor
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Faroe Islands
# Fiji
# Finland
# France
# French Guiana
# French Polynesia
# Gabon
# Gambia
# Gaza Strip
# Georgia
# Germany
# Ghana
# Greece
# Greenland
# Grenada
# Guadeloupe
# Guam
# Guatemala
# ...

# %%
data_folder = "folder_data"
os.makedirs(data_folder, exist_ok=True)

# Create a folder for each CSV file and move the CSV file into its respective folder
for file_name in files:
    folder_name = file_name.replace('.csv', '')  # Remove the '.csv' extension
    folder_path = os.path.join(data_folder, folder_name)  # Path to the folder in the 'data' directory
    file_name = "Final_data/"+file_name
    os.makedirs(folder_path, exist_ok=True)  # Create the folder in the 'data' directory, if it doesn't exist
    shutil.move(file_name, folder_path)  # Move the CSV file into its respective folder in the 'data' directory

# Check if the folders and files are moved correctly
folders_with_files = {}
for folder in os.listdir(data_folder):
    folder_path = os.path.join(data_folder, folder)
    if os.path.isdir(folder_path):
        files_in_folder = os.listdir(folder_path)
        folders_with_files[folder] = files_in_folder

print("Folders with corresponding CSV files in the 'data' directory:")
for folder, files in folders_with_files.items():
    print(folder + ":")
    print(files)
# Out:
# Folders with corresponding CSV files in the 'data' directory:
# Bhutan:
# ['Bhutan.csv']
# Kiribati:
# ['Kiribati.csv']
# Kenya:
# ['Kenya.csv']
# West Bank:
# ['West Bank.csv']
# Afghanistan:
# ['Afghanistan.csv']
# Botswana:
# ['Botswana.csv']
# Benin:
# ['Benin.csv']
# Poland:
# ['Poland.csv']
# Tunisia:
# ['Tunisia.csv']
# Honduras:
# ['Honduras.csv']
# Belarus:
# ['Belarus.csv']
# Guyana:
# ['Guyana.csv']
# Syria:
# ['Syria.csv']
# Sweden:
# ['Sweden.csv']
# Korea, North:
# ['Korea, North.csv']
# Russia:
# ['Russia.csv']
# Norway:
# ['Norway.csv']
# Tanzania:
# ['Tanzania.csv']
# Luxembourg:
# ['Luxembourg.csv']
# Sri Lanka:
# ['Sri Lanka.csv']
# Netherlands Antilles:
# ['Netherlands Antilles.csv']
# Mauritius:
# ['Mauritius.csv']
# Namibia:
# ['Namibia.csv']
# Cyprus:
# ['Cyprus.csv']
# Brazil:
# ['Brazil.csv']
# Faroe Islands:
# ['Faroe Islands.csv']
# Kyrgyzstan:
# ['Kyrgyzstan.csv']
# Bosnia & Herzegovina:
# ['Bosnia & Herzegovina.csv']
# Zambia:
# ['Zambia.csv']
# Ghana:
# ...
